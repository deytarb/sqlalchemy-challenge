# %% [markdown]
# # Bonus: Temperature Analysis I

# %%
import pandas as pd
from collections import namedtuple

# %%
# "tobs" is "temperature observations"
df = pd.read_csv('hawaii_measurements.csv')
df.head()
# Out:
#        station        date  prcp  tobs
# 0  USC00519397  2010-01-01  0.08    65
# 1  USC00519397  2010-01-02  0.00    63
# 2  USC00519397  2010-01-03  0.00    74
# 3  USC00519397  2010-01-04  0.00    76
# 4  USC00519397  2010-01-06   NaN    73

# %%
# Convert the date column format from string to datetime

df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df.head()
# Out:
#        station       date  prcp  tobs
# 0  USC00519397 2010-01-01  0.08    65
# 1  USC00519397 2010-01-02  0.00    63
# 2  USC00519397 2010-01-03  0.00    74
# 3  USC00519397 2010-01-04  0.00    76
# 4  USC00519397 2010-01-06   NaN    73

# %%
# Set the date column as the DataFrame index

df.set_index('date')
# Out:
#                 station  prcp  tobs
# date
# 2010-01-01  USC00519397  0.08    65
# 2010-01-02  USC00519397  0.00    63
# 2010-01-03  USC00519397  0.00    74
# 2010-01-04  USC00519397  0.00    76
# 2010-01-06  USC00519397   NaN    73
# ...                 ...   ...   ...
# 2017-08-19  USC00516128  0.09    71
# 2017-08-20  USC00516128   NaN    78
# 2017-08-21  USC00516128  0.56    76
# 2017-08-22  USC00516128  0.50    76
# 2017-08-23  USC00516128  0.45    76
#
# [19550 rows x 3 columns]

# %%
# Drop the date column

# %% [markdown]
# ### Compare June and December data across all years

# %%
from scipy import stats

# %%
# Filter data for desired months

df['month'] = pd.DatetimeIndex(df['date']).month
jun = df.loc[df['month'] == 6]
dec = df.loc[df['month'] == 12]
df = df.drop(['month'], axis=1)
jun = jun.drop(['month'], axis=1)
dec = dec.drop(['month'], axis=1)
print(jun.head())
print(dec.head())
# Out:
#          station       date  prcp  tobs
# 133  USC00519397 2010-06-01  0.00    78
# 134  USC00519397 2010-06-02  0.01    76
# 135  USC00519397 2010-06-03  0.00    78
# 136  USC00519397 2010-06-04  0.00    76
# 137  USC00519397 2010-06-05  0.00    77
#          station       date  prcp  tobs
# 305  USC00519397 2010-12-01  0.04    76
# 306  USC00519397 2010-12-03  0.00    74
# 307  USC00519397 2010-12-04  0.00    74
# 308  USC00519397 2010-12-06  0.00    64
# 309  USC00519397 2010-12-07  0.00    64

# %%
# Identify the average temperature for June

aveJun = jun['tobs'].mean()

print(aveJun)
# Out:
# 74.94411764705882

# %%
# Identify the average temperature for December

aveDec = dec['tobs'].mean()

print(aveDec)
# Out:
# 71.04152933421226

# %%
# Create collections of temperature data

collectionJun = jun['tobs'].to_dict()
collectionDec = jun['tobs'].to_dict()

print(collectionJun)
print(collectionDec)
# Out:
# {133: 78, 134: 76, 135: 78, 136: 76, 137: 77, 138: 78, 139: 77, 140: 78, 141: 78, 142: 79, 143: 78, 144: 78, 145: 78, 146: 77, 147: 78, 148: 78, 149: 77, 150: 77, 151: 82, 152: 78, 153: 78, 154: 78, 155: 78, 156: 78, 157: 77, 158: 76, 159: 78, 160: 78, 161: 78, 162: 78, 470: 77, 471: 78, 472: 73, 473: 70, 474: 76, 475: 77, 476: 77, 477: 77, 478: 77, 479: 78, 480: 77, 481: 77, 482: 78, 483: 78, 484: 77, 485: 78, 486: 78, 487: 75, 488: 76, 489: 76, 490: 77, 491: 78, 492: 76, 493: 77, 494: 75, 495: 77, 823: 76, 824: 76, 825: 75, 826: 77, 827: 77, 828: 76, 829: 78, 830: 77, 831: 76, 832: 77, 833: 76, 834: 76, 835: 77, 836: 77, 837: 78, 838: 77, 839: 77, 840: 77, 841: 76, 842: 75, 843: 76, 844: 76, 845: 77, 846: 76, 847: 73, 848: 73, 849: 75, 850: 77, 851: 76, 852: 77, 1187: 79, 1188: 78, 1189: 79, 1190: 78, 1191: 78, 1192: 79, 1193: 77, 1194: 77, 1195: 77, 1196: 77, 1197: 77, 1198: 78, 1199: 77, 1200: 76, 1201: 78, 1202: 78, 1203: 77, 1204: 78, 1205: 78, 1206: 73, 1207: 76, 1208: 77, 120
# ...

# %%
# Run paired t-test

stats.ttest_ind(jun['tobs'], dec['tobs'])
# Out:
# Ttest_indResult(statistic=31.60372399000329, pvalue=3.9025129038616655e-191)

# %% [markdown]
# ### Analysis
